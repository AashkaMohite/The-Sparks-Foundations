# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
#read data
df = pd.read_csv("SampleSuperstore.csv")

# %%
# head
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# describe
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# isnull
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# drop country and postal code
df.drop(["Country","Postal Code"], axis=1, inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data = df,diag_kind = "kde")
plt.show()

# %%
plt.title("Sales Vs Profit")
sns.scatterplot('Sales','Profit', data=df)
# Out:
# <AxesSubplot:title={'center':'Sales Vs Profit'}, xlabel='Sales', ylabel='Profit'>

# %%
#sns.scatterplot('Sales','Profit', data=df, hue='Quantity')

# %%
#sns.scatterplot('Sales','Profit', data=df, hue='Category')

# %%
sns.lineplot('Discount','Profit', data=df)
plt.grid()

# %%
df.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap="rainbow")
plt.xlabel('Sales')
plt.ylabel('Total Profits')
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)
plt.show()

# %% [markdown]
# #### Ship Mode

# %%
# value_count
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.title('Ship Mode')
plt.pie(df['Ship Mode'].value_counts(), labels=df['Ship Mode'].value_counts().index,autopct='%1.1f%%',textprops = textprops, shadow=True, colors=colors)
plt.show()

# %%
sns.countplot('Ship Mode',data=df,hue='Category')
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
pls=df.groupby('Ship Mode')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
pls[:].plot.bar(colormap='viridis',figsize=(20,10))
plt.xlabel('Ship Mode')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# #### Segment

# %%
df["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
colors=['#900C3F','#C70039','#FFC300']
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Segment')
plt.pie(df['Segment'].value_counts(), labels=df['Segment'].value_counts().index,autopct='%1.1f%%',textprops = textprops, shadow=True, colors=colors)
plt.show()

# %%
sns.countplot('Segment',data=df,hue='Category')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
pls=df.groupby('Segment')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
pls[:].plot.bar(colormap='jet',figsize=(20,10))
plt.xlabel('Segment')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %%
df["City"].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Portage            1
# Orland Park        1
# Baytown            1
# Tinley Park        1
# Conroe             1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# #### Sate

# %%
df["State"].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot('State',data=df)
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pls=df.groupby('State')[['Sales','Profit']].sum().sort_values(by='Profit',ascending=True)
pls[:].plot.barh(colormap='summer',figsize=(20,30))
plt.xlabel('State')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# #### Region

# %%
df["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
colors=['#FF499E','#D264B6','#A480CF','#779BE7']
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Region')
plt.pie(df['Region'].value_counts(), labels=df['Region'].value_counts().index,autopct='%1.1f%%',textprops = textprops, shadow=True, colors=colors)
plt.show()

# %%
sns.countplot("Region",data=df, hue="Category")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
pls=df.groupby('Region')[['Sales','Profit']].sum().sort_values(by='Profit',ascending=False)
pls[:].plot.bar(colormap='copper_r')
plt.xlabel('Region')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# #### Category

# %%
df["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
colors=['#FFB5BF','#FF8DBC','#5A4E7C']
plt.figure(figsize = (6,6))
textprops = {"fontsize":15}
plt.title('Category')
plt.pie(df['Category'].value_counts(), labels=df['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops, shadow=True, colors=colors)
plt.show()

# %%
pls=df.groupby('Category')[['Sales','Profit']].sum().sort_values(by='Profit',ascending=False)
pls[:].plot.bar(colormap='spring')
plt.xlabel('Category')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# #### Sub-Category

# %%
df["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(df["Sub-Category"])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
pls=df.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Profit',ascending=False)
pls[:].plot.bar(colormap='cividis',figsize=(20,7))
plt.xlabel('Sub-Category')
plt.ylabel('Profit/Loss and Sales')
plt.show()
